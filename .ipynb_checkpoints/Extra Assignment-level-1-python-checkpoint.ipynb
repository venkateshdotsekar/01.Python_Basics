# %%
#print Statement

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
#Buy Input

# %%
name = str(input("Enter your institute name? : "))
# Out:
# Enter your institute name? :  HOPE AI

# %%
#Addition

# %%
Num1=float(input("Num1= "))
Num2=float(input("Num2= "))
result=Num1+Num2
print("Add= ", result)
# Out:
# Num1=  5
# Num2=  6
# Add=  11.0

# %%
#Subtraction

# %%
Num1=float(input("Enter Num1: "))
while True:
    Num2=float(input("Enter Num2 lesser than or equal to Num1: "))
    if(Num2<=Num1):
        break
    print("Please enter value lesser than or equal to Num1. Please try again")
result=Num1-Num2
print("Sub= ", result)
# Out:
# Enter Num1:  15
# Enter Num2 lesser than or equal to Num1:  19
# Please enter value lesser than or equal to Num1. Please try again
# Enter Num2 lesser than or equal to Num1:  15
# Sub=  0.0

# %%
#Multiplication

# %%
Num1=float(input("Num1= "))
Num2=float(input("Num2= "))
result=Num1*Num2
print("Multiply= ", result)
# Out:
# Num1=  6
# Num2=  8
# Multiply=  48.0

# %%
#Division

# %%
Num1=float(input("Enter Num1: "))
while True:
    Num2=float(input("Enter Num2 lesser than or equal to Num1: "))
    if(Num2<=Num1):
        break
    print("Please enter value lesser than or equal to Num1. Please try again")
result=Num1/Num2
print("Division= ", result)
# Out:
# Enter Num1:  100
# Enter Num2 lesser than or equal to Num1:  10
# Division=  10.0

# %%
#floor div

# %%
Num1=float(input("Enter Num1: "))
while True:
    Num2=float(input("Enter Num2 lesser than or equal to Num1: "))
    if(Num2<=Num1):
        break
    print("Please enter value lesser than or equal to Num1. Please try again")
result=Num1//Num2
print("Floor Division= ", result)
# Out:
# Enter Num1:  100
# Enter Num2 lesser than or equal to Num1:  11
# Floor Division=  9.0

# %%
#Modulo

# %%
Num1=float(input("Enter Num1: "))
while True:
    Num2=float(input("Enter Num2 lesser than or equal to Num1: "))
    if(Num2<=Num1):
        break
    print("Please enter value lesser than or equal to Num1. Please try again")
result=Num1%Num2
print("Reminder= ", result)
# Out:
# Enter Num1:  100
# Enter Num2 lesser than or equal to Num1:  11
# Reminder=  1.0
