# %%
""" Problem statement
Get input for salary and age.
If salary greater than or equal to 20000 or age less than or equal to 25, get input for required loan amount. 
    If required loan amount is less than or equal to 50,000 print You are eligible for loan. 
    If loan amount is greater than 50,000 print maximum loan amount is 50,000
If not, print you are not eligible for loan.
"""

salary = int(input("Please enter the salary: "))
print(salary)
age = int(input("Please enter the age: "))
print(age)
if(salary>=20000 or age<=25):
    loan=int(input("Please enter the required loan amount: "))
    if(loan<=50000):
        print("You are elegible for the loan")
    else:
        print("Maximum loan amount is Rs.50000")
else:
    print("You are not elegible for the loan")
# Out:
# Please enter the salary:  21000
# 21000
# Please enter the age:  24
# 24
# Please enter the required loan amount:  51000
# Maximum loan amount is Rs.50000
