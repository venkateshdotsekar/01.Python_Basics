# %%
"""
if(False): #or use if(True)
    print("Yes")
else:
    print("No")
"""
rcb=input("Please enter whether RCB 'win' or 'lose' ? ")
if(rcb=="win"):
    print("We win")
else:
    print("We lose")
